# %%
1+1
# Out:
# 2

# %%
ls=[1,2,3,4,5]
ls[-1:-3]
# Out:
# []

# %%
import math
sqrt(16)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import math
# ----> 2 sqrt(16)
#
# NameError: name 'sqrt' is not defined

# %%
# Out:
# 5.0
